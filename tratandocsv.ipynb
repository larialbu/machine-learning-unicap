# %% [markdown]
# <a href="https://colab.research.google.com/github/larialbu/machine-learning-unicap/blob/master/tratandocsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import datasets,layers,models

# %%
df = pd.read_csv("covidvacina2021.csv")

# %%
df
# Out:
#            _id  faixa_etaria  idade       sexo raca_cor municipio  \
# 0            1  35 a 39 anos     35  MASCULINO    PARDA    RECIFE
# 1            2  35 a 39 anos     36  MASCULINO   BRANCA    RECIFE
# 2            3  30 a 34 anos     34   FEMININO    PARDA    RECIFE
# 3            4  35 a 39 anos     38   FEMININO    PARDA    RECIFE
# 4            5  35 a 39 anos     35  MASCULINO   BRANCA    RECIFE
# ...        ...           ...    ...        ...      ...       ...
# 273800  273801  20 a 24 anos     21   FEMININO    PARDA    RECIFE
# 273801  273802  20 a 24 anos     20  MASCULINO    PRETA    RECIFE
# 273802  273803    5 a 9 anos      8  MASCULINO    PARDA    RECIFE
# 273803  273804  10 a 14 anos     11  MASCULINO    PARDA    RECIFE
# 273804  273805  10 a 14 anos     11  MASCULINO    PARDA    RECIFE
#
#                                         grupo              categoria  \
# 0             PÚBLICO EM GERAL (18 a 59 anos)                    NaN
# ...

# %%
df.loc[0]
# Out:
# _id                                                                1
# faixa_etaria                                            35 a 39 anos
# idade                                                             35
# sexo                                                       MASCULINO
# raca_cor                                                       PARDA
# municipio                                                     RECIFE
# grupo                                PÚBLICO EM GERAL (18 a 59 anos)
# categoria                                                        NaN
# lote                                                          FM2967
# vacina_fabricante                             3 - COMIRNATY (PFIZER)
# descricao_dose                                                     2
# cnes                 DS 8: CNES: 0001198 - UBT ARISTARCHO DE AZEVEDO
# sistema_origem                                        Conecta Recife
# data_vacinacao                                   2022-02-02T00:00:00
# ...

# %%
df['idade']
# Out:
# 0         35
# 1         36
# 2         34
# 3         38
# 4         35
#           ..
# 273800    21
# 273801    20
# 273802     8
# 273803    11
# 273804    11
# Name: idade, Length: 273805, dtype: int64

# %% [markdown]
# ACESSA O VALOR DA LINHA 2 E DA COLUNA IDADE

# %%
df.loc[2, 'idade']
# Out:
# 34

# %% [markdown]
# EXCLOI UMA COLUNA

# %%
df = df.drop('categoria', axis=1)

# %%
df.loc[0]
# Out:
# _id                                                                1
# faixa_etaria                                            35 a 39 anos
# idade                                                             35
# sexo                                                       MASCULINO
# raca_cor                                                       PARDA
# municipio                                                     RECIFE
# grupo                                PÚBLICO EM GERAL (18 a 59 anos)
# lote                                                          FM2967
# vacina_fabricante                             3 - COMIRNATY (PFIZER)
# descricao_dose                                                     2
# cnes                 DS 8: CNES: 0001198 - UBT ARISTARCHO DE AZEVEDO
# sistema_origem                                        Conecta Recife
# data_vacinacao                                   2022-02-02T00:00:00
# Name: 0, dtype: object

# %%
display(df.info())
print()
display(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273805 entries, 0 to 273804
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   _id                273805 non-null  int64
#  1   faixa_etaria       273805 non-null  object
#  2   idade              273805 non-null  int64
#  3   sexo               273805 non-null  object
#  4   raca_cor           273761 non-null  object
#  5   municipio          273805 non-null  object
#  6   grupo              273805 non-null  object
#  7   lote               273782 non-null  object
#  8   vacina_fabricante  273805 non-null  object
#  9   descricao_dose     273805 non-null  int64
#  10  cnes               273805 non-null  object
#  11  sistema_origem     273805 non-null  object
#  12  data_vacinacao     273804 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 27.2+ MB
# None
# (273805, 13)

# %%
df.columns.to_list()
# Out:
# ['_id',
#  'faixa_etaria',
#  'idade',
#  'sexo',
#  'raca_cor',
#  'municipio',
#  'grupo',
#  'lote',
#  'vacina_fabricante',
#  'descricao_dose',
#  'cnes',
#  'sistema_origem',
#  'data_vacinacao']

# %%
grafico1 = df.copy()
grafico1 = grafico1[['idade','lote']]
grafico1.describe().transpose()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# idade  273805.0  32.161012  21.014437  5.0  11.0  27.0  54.0  118.0
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['count']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'count'}, axis=1)
#               .sort_values('count', ascending=True))
#   xs = counted['count']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('count', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# ...

# %% [markdown]
# DADOS FALTOSOS

# %%
df.isna()
# Out:
#           _id  faixa_etaria  idade   sexo  raca_cor  municipio  grupo   lote  \
# 0       False         False  False  False     False      False  False  False
# 1       False         False  False  False     False      False  False  False
# 2       False         False  False  False     False      False  False  False
# 3       False         False  False  False     False      False  False  False
# 4       False         False  False  False     False      False  False  False
# ...       ...           ...    ...    ...       ...        ...    ...    ...
# 273800  False         False  False  False     False      False  False  False
# 273801  False         False  False  False     False      False  False  False
# 273802  False         False  False  False     False      False  False  False
# 273803  False         False  False  False     False      False  False  False
# 273804  False         False  False  False     False      False  False  False
#
# ...

# %% [markdown]
# DADOS FALTOSOS EM CADA COLUNA

# %%
df.isna().sum()
# Out:
# _id                   0
# faixa_etaria          0
# idade                 0
# sexo                  0
# raca_cor             44
# municipio             0
# grupo                 0
# lote                 23
# vacina_fabricante     0
# descricao_dose        0
# cnes                  0
# sistema_origem        0
# data_vacinacao        1
# dtype: int64

# %% [markdown]
# APAGA REGISTROS COM DADOS FALTANTES

# %%
df = df.dropna(axis=0)
